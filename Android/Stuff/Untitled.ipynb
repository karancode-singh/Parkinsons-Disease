# %%
import pandas as pd

# %%
ctrl_path = "control/"
park_path = "parkinson/"

# %%
df_ctrl = pd.read_csv(ctrl_path + "control_all_with_header.csv")
df_park = pd.read_csv(park_path + "park_all_with_header.csv")
df = pd.concat([df_ctrl, df_park])
df.info(), df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 322967 entries, 0 to 202657
# Data columns (total 9 columns):
# Subject      322967 non-null int64
# X            322967 non-null int64
# Y            322967 non-null int64
# Z            322967 non-null int64
# Pressure     322967 non-null int64
# GripAngle    322967 non-null int64
# Timestamp    322967 non-null int64
# Test_ID      322967 non-null int64
# PWP          322967 non-null int64
# dtypes: int64(9)
# memory usage: 24.6 MB
# (None,    Subject    X    Y   Z  Pressure  GripAngle   Timestamp  Test_ID  PWP
#  0       41  199  202   0       202        860  1732464838        0    0
#  1       41  199  202   0       276        860  1732464845        0    0
#  2       41  199  202  12       328        860  1732464852        0    0
#  3       41  199  202   0       373        860  1732464859        0    0
#  4       41  199  203   0       409        860  1732464866        0    0)

# %%
train_x = df[['X', 'Y', 'Z', 'Pressure', 'GripAngle', 'Timestamp']]
train_y = df[['PWP']]
train_x.info(), train_y.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 322967 entries, 0 to 202657
# Data columns (total 6 columns):
# X            322967 non-null int64
# Y            322967 non-null int64
# Z            322967 non-null int64
# Pressure     322967 non-null int64
# GripAngle    322967 non-null int64
# Timestamp    322967 non-null int64
# dtypes: int64(6)
# memory usage: 17.2 MB
# (None, (322967, 1))

# %%
a = train_x['Timestamp']

# %%
train_x['Timestamp'] = a
# Out:
# /home/imshambles/tensorflow/tensorflow_pkg/tf_1.11.0_cuda10.0/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
train_x
# Out:
#           X    Y    Z  Pressure  GripAngle   Timestamp
# 0       199  202    0       202        860           0
# 1       199  202    0       276        860           7
# 2       199  202   12       328        860          14
# 3       199  202    0       373        860          21
# 4       199  203    0       409        860          28
# 5       199  203    0       436        860          35
# 6       199  203    0       457        860          43
# 7       199  203    0       479        860          50
# 8       199  203    0       501        860          57
# 9       199  203    0       521        860          64
# 10      200  203    0       538        860          71
# 11      200  203    0       548        860          78
# 12      200  203    0       559        860          85
# 13      201  203    0       565        870          92
# 14      201  203    0       568        870          99
# 15      201  203    0       574        870         106
# 16      202  202    0       578        870         113
# 17      202  202    0       580        860         120
# 18      203  202    0       587        870         127
# 19      203  202    0       594        860         134
# 20      203  202    0       599        860         141
# 21      203  202    0       608        860         148
# 22      203  201    0       611        860         155
# 23      204  201    0       616        850         162
# 24      204  201    0       620        860         169
# 25      204  200    0       621        850         176
# 26      205  200    0       627        850         183
# 27      205  199    0       625        850         190
# 28      205  199    0       627        850         197
# 29      205  199    0       629        850         204
# ...     ...  ...  ...       ...        ...         ...
# 202628  288  365  834         0       1330 -1728351308
# 202629  291  367  862         0       1330 -1728351299
# 202630  292  371  874         0       1320 -1728351290
# 202631  293  375  874         0       1290 -1728351281
# 202632  295  381  886         0       1420 -1728351272
# 202633  299  386  902         0       1510 -1728351263
# 202634  300  393  902         0       1600 -1728351254
# 202635  302  400  902         0       1660 -1728351245
# 202636  304  408  902         0       1670 -1728351236
# 202637  307  416  902         0       1690 -1728351227
# 202638  310  424  914         0       1690 -1728351218
# 202639  311  431  926         0       1400 -1728351209
# 202640  313  438  942         0       1270 -1728351200
# 202641  314  445  954         0       1180 -1728351191
# 202642  318  453  942         0       1140 -1728351182
# 202643  319  460  942         0       1200 -1728351173
# 202644  321  467  926         0       1140 -1728351164
# 202645  324  474  926         0       1190 -1728351155
# 202646  326  481  926         0       1110 -1728351146
# 202647  327  489  942         0       1150 -1728351137
# 202648  328  497  926         0       1270 -1728351128
# 202649  331  504  926         0       1200 -1728351119
# 202650  333  512  926         0       1280 -1728351110
# 202651  334  519  926         0       1060 -1728351101
# 202652  336  527  926         0        560 -1728351092
# 202653  338  538  926         0        190 -1728351083
# 202654  341  549  926         0         50 -1728351074
# 202655  342  559  942         0         70 -1728351065
# 202656  343  569  954         0         90 -1728351056
# 202657  343  569  966         0         90 -1728351038
#
# [322967 rows x 6 columns]
